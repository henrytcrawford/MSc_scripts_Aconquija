# %%
## Idenitfy how many pixels need to be avergaed until mean converges to a steady value.

# 1. identify sample SPOTS in raster scene as polygons
# 2. mask raster to only show data within these polygonns
# 3. extract individual pixel values for given Band/wavelength
# 4. sort pixels randomly
# 5. iterativly calculate mean spectral value as pixels are added one at a time. 
# 6. identify number of pixels where mean spectral value begins to stabalize. This is the minimum number of pixels needed to charectorize a targeted surface.
# 7. Conver minimum number of pixels to minimum number of SPOT polygons at the 50-meter, 100-meter, and 150-meter radius (e.g. 9 pixels, 20 pixels, and X pixels each)

# %%
# load libraries

import geopandas as gpd
import rasterio as rio
from rasterio.plot import show
from rasterio.plot import show_hist
from rasterio.mask import mask
import rasterstats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from os import path

# identify working directories for exports
current_dir = os.getcwd() # current directory for scripts/git
parent_dir = os.path.dirname(current_dir) # one level up for exports

# %%
## READ IN DATA 

#locate files
polygons_file = r'C:\Users\htccr\Documents\Aconquija\GIS_data\testing\test_spots_Q7_clean.shp'
target_data_file = r'C:\Users\htccr\Documents\Aconquija\imagery\landsat8\export\clipped\Landsat8_SR_stacked_clipped-surfaces_BCET.tif'
target_sensor = 'Landsat'
target_band = 6

target_band = target_band - 1 # subtract 1 to account or 0 to max range

# read in files
polygons = gpd.read_file(polygons_file)

data_src = rio.open(target_data_file, 'r')
data_profile = data_src.profile
count = data_profile['count'] # How many bands are in our image?

# %%
## ***STOP only create rgb if needed***
rgb_file = parent_dir + '\outputs\\aconquija_rgb_PRISMA.tif'

# create RGB file flor plotting
# Conacate RRGB bands
rgb = data_src.read([34,26,20])
rgb = (rgb * (255 / np.max(rgb))).astype(rio.uint8) # normalize to 0-255 range
#rgb[rgb==0] = np.max(rgb) #put nodata as max value so backround plots white... 

## Save RGB Image and load in for plotting
# Register GDAL format drivers and configuration options with a
# context manager.
with rio.Env():

    # Write an array as a raster band to a new 8-bit file. For
    # the new file's profile, we start with the profile of the source
    profile = data_src.profile

    # And then change the band count to 1, set the
    # dtype to uint8, and specify LZW compression.
    profile.update(
        dtype=rio.uint8,
        count=3,
        nodata = 0,
        compress='lzw')
    
    with rio.open(rgb_file,'w',**profile) as dst:
        dst.write(rgb)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10480/2340953356.py in <module>
#       4 # create RGB file flor plotting
#       5 # Conacate RRGB bands
# ----> 6 rgb = data_src.read([34,26,20])
#       7 rgb = (rgb * (255 / np.max(rgb))).astype(rio.uint8) # normalize to 0-255 range
#       8 #rgb[rgb==0] = np.max(rgb) #put nodata as max value so backround plots white...
#
# rasterio\_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# IndexError: band index 34 out of range (not in (1, 2, 3, 4, 5, 6, 7))

# %%
rgb_file = parent_dir + '\outputs\\aconquija_rgb.tif'

# Read in RGB image
rgb_src = rio.open(rgb_file, 'r')
rgb_profile = rgb_src.profile

# %%
# create polygon of shapefile extent and use to mask full rgb
from shapely.geometry import box

bbox_polygons = polygons.total_bounds # bounding box of shapefile
bbox_polygons = box(*polygons.total_bounds)
bbox_polygons = gpd.GeoDataFrame({"id":1,"geometry":[bbox_polygons]})
extent_polygons = np.array(polygons.total_bounds)

masked, mask_transform = mask(dataset=rgb_src, shapes = bbox_polygons.geometry, crop=True)
#show(masked, transform=mask_transform)

# %%
# plot as check
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (15,10))

show(rgb_src, ax = ax1)
bbox_polygons.plot(ax = ax1, facecolor = 'none', edgecolor = 'red')

show(rgb_src, ax = ax2)
bbox_polygons.plot(ax = ax2, facecolor = 'none', edgecolor = 'red')
polygons.plot(ax = ax2, facecolor = 'none', edgecolor = 'red')
plt.xlim(extent_polygons[0] - 750, extent_polygons[2]+ 750)
plt.ylim(extent_polygons[1] - 750, extent_polygons[3]+ 750)

# image metadata
data_src.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 0.0,
#  'width': 590,
#  'height': 663,
#  'count': 7,
#  'crs': CRS.from_epsg(32719),
#  'transform': Affine(30.0, 0.0, 766665.0,
#         0.0, -30.0, 6997855.0)}

# %%
# mask and keep only pixels within polygons
masked, mask_transform = mask(dataset=data_src, shapes = polygons.geometry, crop=True, all_touched  = False, nodata = data_profile['nodata'])
show(masked[target_band])
# Out:
# <AxesSubplot:>

# %%
# isolate target band
pix = masked[target_band]
pix = pix[pix != 0]

# calulate stats
mean_pix = pix.mean()
max_pix = pix.max()
min_pix = pix.min()
std_pix = pix.std()
count_pix = np.min(np.shape(pix))

# %%
# MOE MINUM N
# function to determine minimum number (n) pixels to reach a designated Margin of Error given a specific confident interval (z score)
def margin_of_error(z, std, MOE):
    n_required = ((z*std)/MOE)**2
    return(n_required)

# variables
z = 1.96 # i.e 95% confidence interval
MOE = 200 # reflectance
  
n_pix_required = margin_of_error(z,std_pix, MOE)
round(n_pix_required,0)
# Out:
# 158.0

# %%
# iterate through pixels and store cumulative means
np.random.shuffle(pix) # randomly sort pixel values

pixel = np.arange(0,count_pix + 1, 1)
means = []

for i in range(0, count_pix + 1):
    means.append(np.mean(pix[0:i]))
    means[0] = pix[0]
# Out:
# C:\Anaconda\envs\geo_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Anaconda\envs\geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
x = pixel
y = means

# approximate first derivative i.e. slope of line between adjacent points
data = pd.DataFrame()
data['y_p'] = np.diff(y) / np.diff(x)
data['x_p'] = (np.array(x)[:-1] + np.array(x)[1:]) / 2

# PLOT 
# plot cumulative means by pixel
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel('n pixels', size = 12)
plt.ylabel('Mean Relative Reflectance', size = 12)
plt.title('Mean Convergence: {} Band {}'.format(target_sensor, target_band), size = 14)
plt.grid()
plt.ylim()

# plot first derivative, should converge at 0
plt.subplot(1,2,2)
plt.plot(data['x_p'], data['y_p'], 'b')
plt.xlabel('n pixels', size = 12)
plt.ylabel('Magnitude', size = 12)
plt.title('First Derivative: {} Band {}'.format(target_sensor, target_band), size = 14)
plt.grid()

plt.show()

# %%
# SINGLE CODE CHUNK

# %%
### - MANUAL CONTROL START---###

#locate files
polygons_file = r'C:\Users\htccr\Documents\Aconquija\GIS_data\testing\test_spots_Q7_clean.shp'
target_data_file = r'C:\Users\htccr\Documents\Aconquija\imagery\landsat8\export\clipped\Landsat8_SR_stacked_clipped-surfaces_BCET.tif'
target_sensor = 'Landsat'
target_band = 1

### - MANUAL CONTROL END---###

## READ IN DATA 
target_band = target_band - 1 # subtract 1 to account or 0 to max range

polygons = gpd.read_file(polygons_file)
bbox_polygons = polygons.total_bounds # bounding box of shapefile

data_src = rio.open(target_data_file, 'r')
data_profile = data_src.profile
count = data_profile['count'] # How many bands are in our image?

## ANALYSIS

# mask and keep only pixels within polygons

masked, mask_transform = mask(dataset=data_src, shapes = polygons.geometry, crop=True, all_touched  = False, nodata = data_profile['nodata'])

# isolate target band
pix = masked[target_band]
pix = pix[pix != 0]

# calulate stats
mean_pix = pix.mean()
max_pix = pix.max()
min_pix = pix.min()
std_pix = pix.std()
count_pix = np.min(np.shape(pix))

# MOE MINUM N
# function to determine minimum number (n) pixels to reach a designated Margin of Error given a specific confident interval (z score)
def margin_of_error(z, std, MOE):
    n_required = ((z*std)/MOE)**2
    return(n_required)

# variables
z = 1.96 # i.e 95% confidence interval
MOE = 200 # reflectance
  
n_pix_required = margin_of_error(z,std_pix, MOE)
round(n_pix_required,0)

# iterate through pixels and store cumulative means
np.random.shuffle(pix) # randomly sort pixel values

pixel = np.arange(0,count_pix + 1, 1)
means = []

for i in range(0, count_pix + 1):
    means.append(np.mean(pix[0:i]))
    means[0] = pix[0]

# call data
x = pixel
y = means

# approximate first derivative i.e. slope of line between adjacent points
data = pd.DataFrame()
data['y_p'] = np.diff(y) / np.diff(x)
data['x_p'] = (np.array(x)[:-1] + np.array(x)[1:]) / 2

# PLOT 
# plot cumulative means by pixel
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel('n pixels', size = 12)
plt.ylabel('Mean Relative Reflectance', size = 12)
plt.title('Mean Convergence: {} Band {}'.format(target_sensor, target_band), size = 14)
plt.xlim()
plt.ylim()
plt.grid()


# plot first derivative, should converge at 0
plt.subplot(1,2,2)
plt.plot(data['x_p'], data['y_p'], 'b')
plt.xlabel('n pixels', size = 12)
plt.ylabel('Magnitude', size = 12)
plt.title('First Derivative: {} Band {}'.format(target_sensor, target_band + 1), size = 14)
plt.xlim()
plt.ylim()
plt.grid()

plt.show()
# Out:
# C:\Anaconda\envs\geo_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Anaconda\envs\geo_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
x_6 = data['x_p']
y_6 = data['y_p']

# %%
x_2 = data['x_p']
y_2 = data['y_p']

# %%
x_4 = data['x_p']
y_4 = data['y_p']

# %%
x_1= data['x_p']
y_1= data['y_p']

# %%
plt.figure(figsize = (15,10))
plt.plot(x_6,y_6, 'b')
plt.plot(x_2,y_2, 'red')
plt.plot(x_4,y_4, 'green')
plt.plot(x_1,y_1, 'yellow')
plt.xlabel('n pixels', size = 12)
plt.ylabel('Magnitude', size = 12)
plt.title('First Derivative: {} Band {}'.format(target_sensor, target_band + 1), size = 14)
plt.xlim()
plt.ylim()
plt.grid()

plt.show()

# %%
# Try to make iterative over all bands

# %%
### - MANUAL CONTROL START---###

#locate files
polygons_file = r'C:\Users\htccr\Documents\Aconquija\GIS_data\testing\test_spots_Q7_clean.shp'
target_data_file = r'C:\Users\htccr\Documents\Aconquija\imagery\landsat8\export\clipped\Landsat8_SR_stacked_clipped-surfaces_BCET.tif'
target_sensor = 'Landsat'
target_band = 6

### - MANUAL CONTROL END---###

## READ IN DATA 
target_band = target_band - 1 # subtract 1 to account or 0 to max range

polygons = gpd.read_file(polygons_file)
bbox_polygons = polygons.total_bounds # bounding box of shapefile

data_src = rio.open(target_data_file, 'r')
data_profile = data_src.profile
count = data_profile['count'] # How many bands are in our image?

## ANALYSIS

# mask and keep only pixels within polygons

masked, mask_transform = mask(dataset=data_src, shapes = polygons.geometry, crop=True, all_touched  = False, nodata = data_profile['nodata'])

# isolate target band
pix = masked[target_band]
pix = pix[pix != 0]

# calulate stats
mean_pix = pix.mean()
max_pix = pix.max()
min_pix = pix.min()
std_pix = pix.std()
count_pix = np.min(np.shape(pix))

# MOE MINUM N
# function to determine minimum number (n) pixels to reach a designated Margin of Error given a specific confident interval (z score)
def margin_of_error(z, std, MOE):
    n_required = ((z*std)/MOE)**2
    return(n_required)

# variables
z = 1.96 # i.e 95% confidence interval
MOE = 200 # reflectance
  
n_pix_required = margin_of_error(z,std_pix, MOE)
round(n_pix_required,0)

# iterate through pixels and store cumulative means
np.random.shuffle(pix) # randomly sort pixel values

pixel = np.arange(0,count_pix + 1, 1)
means = []

for i in range(0, count_pix + 1):
    means.append(np.mean(pix[0:i]))
    means[0] = pix[0]

# call data
x = pixel
y = means

# approximate first derivative i.e. slope of line between adjacent points
data = pd.DataFrame()
data['y_p'] = np.diff(y) / np.diff(x)
data['x_p'] = (np.array(x)[:-1] + np.array(x)[1:]) / 2

# PLOT 
# plot cumulative means by pixel
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.xlabel('n pixels', size = 12)
plt.ylabel('Mean Relative Reflectance', size = 12)
plt.title('Mean Convergence: {} Band {}'.format(target_sensor, target_band), size = 14)
plt.xlim()
plt.ylim()
plt.grid()


# plot first derivative, should converge at 0
plt.subplot(1,2,2)
plt.plot(data['x_p'], data['y_p'], 'b')
plt.xlabel('n pixels', size = 12)
plt.ylabel('Magnitude', size = 12)
plt.title('First Derivative: {} Band {}'.format(target_sensor, target_band), size = 14)
plt.xlim()
plt.ylim()
plt.grid()

plt.show()
